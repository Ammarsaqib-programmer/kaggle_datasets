# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('AI Generated Essays Dataset.csv')

# %%
df.isnull().sum()
# Out:
# text         0
# generated    0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                    text  generated
# 0     Machine learning, a subset of artificial intel...          1
# 1     A decision tree, a prominent machine learning ...          1
# 2     Education, a cornerstone of societal progress,...          1
# 3     Computers, the backbone of modern technology, ...          1
# 4     Chess, a timeless game of strategy and intelle...          1
# ...                                                 ...        ...
# 1455  There has been a fuss about the Elector Colleg...          0
# 1456  Limiting car usage has many advantages. Such a...          0
# 1457  There's a new trend that has been developing f...          0
# 1458  As we all know cars are a big part of our soci...          0
# 1459  Cars have been around since the 1800's and hav...          0
#
# [1460 rows x 2 columns]>

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
x = df['text']
y = df['generated']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = lr_model.predict(X_test_tfidf)

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=['Human', 'AI'])
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Let's create a simple function to predict if a given essay/sentence is Human or AI
def predict_text_origin(text):
    text_tfidf = tfidf.transform([text])
    pred = lr_model.predict(text_tfidf)[0]
    label = "AI-generated" if pred == 1 else "Human-written"
    return label

# Example prediction
example_texts = [
    "The quick brown fox jumps over the lazy dog.",
    "Artificial intelligence is revolutionizing the way we write essays."
]

example_predictions = {txt: predict_text_origin(txt) for txt in example_texts}
example_predictions
# Out:
# {'The quick brown fox jumps over the lazy dog.': 'Human-written',
#  'Artificial intelligence is revolutionizing the way we write essays.': 'Human-written'}

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_words = 600  # vocabulary size
max_len = 50     # sequence length

tokenizer = Tokenizer(num_words=max_words, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)
x_train = tokenizer.texts_to_sequences(X_train)
x_test = tokenizer.texts_to_sequences(X_test)

x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=100, input_length=max_len))
model.add(LSTM(128, dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# c:\Program Files\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(x_train, y_train, validation_data=(x_test, y_test),
          epochs=32, batch_size=64)
# Out:
# Epoch 1/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 199ms/step - accuracy: 0.8654 - loss: 0.5263 - val_accuracy: 0.9315 - val_loss: 0.2488
# Epoch 2/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9558 - loss: 0.1795 - val_accuracy: 0.9418 - val_loss: 0.2235
# Epoch 3/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.9668 - loss: 0.1481 - val_accuracy: 0.9452 - val_loss: 0.1975
# Epoch 4/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - accuracy: 0.9576 - loss: 0.1506 - val_accuracy: 0.9726 - val_loss: 0.0872
# Epoch 5/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.9837 - loss: 0.0474 - val_accuracy: 0.9795 - val_loss: 0.0910
# Epoch 6/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.9890 - loss: 0.0364 - val_accuracy: 0.9795 - val_loss: 0.0843
# Epoch 7/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.9890 - loss: 0.0352 - val_accuracy: 0.9897 - val_loss: 0.0454
# Epoch 8/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.9933 - loss: 0.0238 - val_accuracy: 0.9966 - val_loss: 0.0372
# Epoch 9/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.9938 - loss: 0.0238 - val_accuracy: 0.9966 - val_loss: 0.0364
# Epoch 10/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.9976 - loss: 0.0178 - val_accuracy: 0.9966 - val_loss: 0.0363
# Epoch 11/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.9987 - loss: 0.0134 - val_accuracy: 0.9829 - val_loss: 0.0711
# Epoch 12/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9957 - loss: 0.0195 - val_accuracy: 0.9966 - val_loss: 0.0321
# Epoch 13/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9994 - loss: 0.0065 - val_accuracy: 0.9966 - val_loss: 0.0314
# Epoch 14/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9959 - loss: 0.0144 - val_accuracy: 0.9863 - val_loss: 0.0501
# Epoch 15/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.9977 - loss: 0.0122 - val_accuracy: 0.9897 - val_loss: 0.0447
# Epoch 16/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9960 - loss: 0.0197 - val_accuracy: 0.9966 - val_loss: 0.0310
# Epoch 17/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9985 - loss: 0.0091 - val_accuracy: 0.9966 - val_loss: 0.0306
# Epoch 18/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9942 - loss: 0.0241 - val_accuracy: 0.9829 - val_loss: 0.0966
# Epoch 19/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 0.9965 - loss: 0.0218 - val_accuracy: 0.9932 - val_loss: 0.0407
# Epoch 20/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9970 - loss: 0.0108 - val_accuracy: 0.9966 - val_loss: 0.0349
# Epoch 21/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.9997 - loss: 0.0064 - val_accuracy: 0.9863 - val_loss: 0.0736
# Epoch 22/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9966 - loss: 0.0152 - val_accuracy: 0.9932 - val_loss: 0.0454
# Epoch 23/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9984 - loss: 0.0105 - val_accuracy: 0.9863 - val_loss: 0.0714
# Epoch 24/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.9961 - loss: 0.0158 - val_accuracy: 0.9863 - val_loss: 0.0534
# Epoch 25/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9960 - loss: 0.0162 - val_accuracy: 0.9966 - val_loss: 0.0419
# Epoch 26/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9976 - loss: 0.0106 - val_accuracy: 0.9966 - val_loss: 0.0372
# Epoch 27/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9966 - val_loss: 0.0347
# Epoch 28/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.9975 - loss: 0.0098 - val_accuracy: 0.9966 - val_loss: 0.0352
# Epoch 29/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 257ms/step - accuracy: 0.9997 - loss: 0.0030 - val_accuracy: 0.9966 - val_loss: 0.0356
# Epoch 30/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.9976 - loss: 0.0078 - val_accuracy: 0.9966 - val_loss: 0.0373
# Epoch 31/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9972 - loss: 0.0045 - val_accuracy: 0.9966 - val_loss: 0.0367
# Epoch 32/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - accuracy: 0.9984 - loss: 0.0029 - val_accuracy: 0.9932 - val_loss: 0.0433

# %%
# Basic evaluation (loss, accuracy)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Loss: 0.0433
# Test Accuracy: 0.9932

# %%
y_prob = model.predict(x_test, batch_size=128).ravel()
threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_recall_fscore_support,
    roc_auc_score,
    roc_curve,
    precision_recall_curve
)

acc = accuracy_score(y_test, y_pred)
print(f"Accuracy (threshold={threshold}): {acc:.4f}")

print(classification_report(
    y_test,
    y_pred,
    target_names=["Human", "AI"]
))

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Accuracy (threshold=0.5): 0.9932
#               precision    recall  f1-score   support
#
#        Human       0.99      1.00      1.00       272
#           AI       1.00      0.90      0.95        20
#
#     accuracy                           0.99       292
#    macro avg       1.00      0.95      0.97       292
# weighted avg       0.99      0.99      0.99       292
#
# Confusion Matrix:
# [[272   0]
#  [  2  18]]
